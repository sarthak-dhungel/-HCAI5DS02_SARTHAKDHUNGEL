# %% [markdown]
# # Title: California Housing Data Analysis using **Pandas**
#
# ---

# %%
# Import necessary libraries
import pandas as pd
from sklearn.datasets import fetch_california_housing

# %% [markdown]
# Load the dataset as a pandas DataFrame

# %%
data = fetch_california_housing(as_frame=True)
df = data.frame

# %%
# Display first 5 rows
print("First 5 rows of the dataset:")
print(df.head())
# Out:
# First 5 rows of the dataset:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# Display basic info about the dataset
print("\nDataset Info:")
print(df.info())
# Out:
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB
# None

# %%
# Display statistical summary
print("\nStatistical Summary:")
print(df.describe())
# Out:
# Statistical Summary:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude   MedHouseVal
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %% [markdown]
# # **Problem 1 – Sorting**

# %%
# 1. Create a DataFrame with only the 'MedInc' column
med_income = df[['MedInc']]
print("First 5 rows of Median Income:")
print(med_income.head())
# Out:
# First 5 rows of Median Income:
#    MedInc
# 0  8.3252
# 1  8.3014
# 2  7.2574
# 3  5.6431
# 4  3.8462

# %%
# 2. Create a DataFrame with 'Population' and 'Latitude' columns
pop_lat = df[['Population', 'Latitude']]
print("\nFirst 5 rows of Population and Latitude:")
print(pop_lat.head())
# Out:
# First 5 rows of Population and Latitude:
#    Population  Latitude
# 0       322.0     37.88
# 1      2401.0     37.86
# 2       496.0     37.85
# 3       558.0     37.85
# 4       565.0     37.85

# %%
# 3. Create a DataFrame with 'HouseAge' and 'AveRooms' columns
house_age_rooms = df[['HouseAge', 'AveRooms']]
print("\nFirst 5 rows of House Age and Average Rooms:")
print(house_age_rooms.head())
# Out:
# First 5 rows of House Age and Average Rooms:
#    HouseAge  AveRooms
# 0      41.0  6.984127
# 1      21.0  6.238137
# 2      52.0  8.288136
# 3      52.0  5.817352
# 4      52.0  6.281853

# %% [markdown]
# # A. Subsetting Rows

# %%
# 1. Filter where MedInc > 8.0
high_income = df[df['MedInc'] > 8.0]
print("High Income Houses (MedInc > 8.0):")
print(high_income.head())
# Out:
# High Income Houses (MedInc > 8.0):
#       MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0     8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1     8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 131  11.6017      18.0  8.335052   1.082474       533.0  2.747423     37.84
# 134   8.2049      28.0  6.978947   0.968421       463.0  2.436842     37.83
# 135   8.4010      26.0  7.530806   1.056872       542.0  2.568720     37.83
#
#      Longitude  MedHouseVal
# 0      -122.23        4.526
# 1      -122.22        3.585
# 131    -122.19        3.926
# 134    -122.19        3.352
# 135    -122.20        3.512

# %%
# 2. Filter where Latitude > 37
north_california = df[df['Latitude'] > 37]
print("\nHouses in North California (Latitude > 37):")
print(north_california.head())
# Out:
# Houses in North California (Latitude > 37):
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23        4.526
# 1    -122.22        3.585
# 2    -122.24        3.521
# 3    -122.25        3.413
# 4    -122.25        3.422

# %%
# 3. Filter where AveRooms > 6.0 and AveOccup < 2.0
spacious_low_occupancy = df[(df['AveRooms'] > 6.0) & (df['AveOccup'] < 2.0)]
print("\nSpacious Low Occupancy Houses (AveRooms > 6.0 and AveOccup < 2.0):")
print(spacious_low_occupancy.head())
# Out:
# Spacious Low Occupancy Houses (AveRooms > 6.0 and AveOccup < 2.0):
#       MedInc  HouseAge   AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 418   6.1593      41.0   6.215470   1.077348       356.0  1.966851     37.89
# 648   6.5095      25.0   6.631579   0.894737       340.0  1.988304     37.72
# 710   2.4196      26.0   8.518248   2.700730       253.0  1.846715     37.68
# 1024  3.1500      16.0  29.852941   5.323529       202.0  1.980392     38.52
# 1102  2.4028      17.0  31.777778   9.703704        47.0  1.740741     40.06
#
#       Longitude  MedHouseVal
# 418     -122.25        3.440
# 648     -122.13        3.712
# 710     -122.08        2.750
# 1024    -120.00        1.406
# 1102    -121.54        0.675

# %% [markdown]
# # B. Subsetting Categorical Equivalents

# %%
# 1. Create 'Region' column based on Latitude
def categorize_region(lat):
    if lat > 37:
        return 'North'
    elif lat > 35:
        return 'Central'
    else:
        return 'South'

df['Region'] = df['Latitude'].apply(categorize_region)

# %%
# 2. Filter where Region is 'North' or 'Central'
north_central_region = df[df['Region'].isin(['North', 'Central'])]
print("\nHouses in North or Central Region:")
print(north_central_region.head())
# Out:
# Houses in North or Central Region:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal Region
# 0    -122.23        4.526  North
# 1    -122.22        3.585  North
# 2    -122.24        3.521  North
# 3    -122.25        3.413  North
# 4    -122.25        3.422  North

# %% [markdown]
# # Problem 3 – Exploratory Data Analysis (EDA)

# %%
# A. Value per room analysis

# 1. Create new column
df['value_per_room'] = df['MedHouseVal'] / df['AveRooms']

# 2. Filter where value_per_room > 1
high_vpr = df[df['value_per_room'] > 1]

# 3. Sort by descending value_per_room
high_vpr_sorted = high_vpr.sort_values(by='value_per_room', ascending=False)

# 4. Display top 5 rows
print("Top 5 houses with highest value per room:")
print(high_vpr_sorted[['MedHouseVal', 'AveRooms', 'value_per_room']].head())
# Out:
# Top 5 houses with highest value per room:
#        MedHouseVal  AveRooms  value_per_room
# 15660      5.00001  1.824719        2.740153
# 15654      4.50000  1.902087        2.365823
# 4559       5.00001  2.148148        2.327591
# 15652      5.00001  2.237474        2.234667
# 15661      5.00001  2.297872        2.175930

# %% [markdown]
# B. Q2: In high population areas, who has the highest income per person?

# %%
# B. Income per person in high population areas

# 1. Create income per person column
df['income_per_person'] = df['MedInc'] / df['Population']

# 2. Filter where Population > 5000
dense_areas = df[df['Population'] > 5000]

# 3. Sort by descending income_per_person
rich_dense_areas = dense_areas.sort_values(by='income_per_person', ascending=False)

# 4. Display top 5 rows
print("\nTop 5 high population areas with highest income per person:")
print(rich_dense_areas[['MedInc', 'Population', 'income_per_person']].head())
# Out:
# Top 5 high population areas with highest income per person:
#        MedInc  Population  income_per_person
# 9004   9.1232      5452.0           0.001673
# 20427  8.6499      5495.0           0.001574
# 9027   7.7848      5175.0           0.001504
# 5724   8.1657      5459.0           0.001496
# 9013   9.1228      6214.0           0.001468

# %% [markdown]
# # Problem 4 – GroupBy Exercises

# %%
# A. Percentage of total house value by Region

# 1. Total house value
total_house_value = df['MedHouseVal'].sum()

# 2. Sum of MedHouseVal per region
region_value_sum = df.groupby('Region')['MedHouseVal'].sum()

# 3. Percentage share
region_value_percent = (region_value_sum / total_house_value) * 100

print("Percentage of total house value from each Region:")
print(region_value_percent)
# Out:
# Percentage of total house value from each Region:
# Region
# Central     5.195671
# North      36.267665
# South      58.536663
# Name: MedHouseVal, dtype: float64

# %% [markdown]
# B. Q2: What percent of total houses belong to different age groups?

# %%
# B. Age group distribution

# 1. Define AgeGroup column
def assign_age_group(age):
    if age < 20:
        return 'New'
    elif age < 40:
        return 'Mid'
    else:
        return 'Old'

df['AgeGroup'] = df['HouseAge'].apply(assign_age_group)

# 2. Total houses
total_houses = len(df)

# 3. Count per age group
age_group_counts = df['AgeGroup'].value_counts()

# 4. Percentage share
age_group_percent = (age_group_counts / total_houses) * 100

print("\nPercentage of houses by Age Group:")
print(age_group_percent)
# Out:
# Percentage of houses by Age Group:
# AgeGroup
# Mid    51.501938
# New    28.236434
# Old    20.261628
# Name: count, dtype: float64

# %% [markdown]
# Advanced Exercises – Correlation Analysis & Missing Data Handling

# %%
# A. Pearson correlation with MedHouseVal

# Calculate correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Extract correlations with MedHouseVal
correlations_with_target = correlation_matrix['MedHouseVal'].sort_values(ascending=False)

print("Correlation of features with MedHouseVal:")
print(correlations_with_target)
# Out:
# Correlation of features with MedHouseVal:
# MedHouseVal          1.000000
# value_per_room       0.823007
# MedInc               0.688075
# AveRooms             0.151948
# income_per_person    0.114455
# HouseAge             0.105623
# AveOccup            -0.023737
# Population          -0.024650
# Longitude           -0.045967
# AveBedrms           -0.046701
# Latitude            -0.144160
# Name: MedHouseVal, dtype: float64

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Backup original column
df['AveRooms_original'] = df['AveRooms'].copy()

# 1. Introduce 5% NaNs in AveRooms
np.random.seed(42)  # for reproducibility
missing_indices = df.sample(frac=0.05).index
df.loc[missing_indices, 'AveRooms'] = np.nan

print(f"\nNumber of missing values in AveRooms after simulation: {df['AveRooms'].isna().sum()}")

# 2. Impute with median
median_value = df['AveRooms'].median()
df['AveRooms'] = df['AveRooms'].fillna(median_value)

print(f"Missing values after imputation: {df['AveRooms'].isna().sum()}")

# 3. Visualize before and after imputation
plt.figure(figsize=(12, 5))

# Before
plt.subplot(1, 2, 1)
sns.histplot(df['AveRooms_original'], kde=True, bins=30, color='skyblue')
plt.title("AveRooms - Original Distribution")

# After
plt.subplot(1, 2, 2)
sns.histplot(df['AveRooms'], kde=True, bins=30, color='lightgreen')
plt.title("AveRooms - After Median Imputation")

plt.tight_layout()
plt.show()
# Out:
# Number of missing values in AveRooms after simulation: 1032
# Missing values after imputation: 0

# %% [markdown]
# # 2. Numpy: Advanced Exercises

# %%
import numpy as np

# 3x1 column vector
col_vector = np.array([[1], [2], [3]])

# 1x4 row vector
row_vector = np.array([[10, 20, 30, 40]])

# Broadcasting multiplication
broadcasted_result = col_vector * row_vector

print("3x1 column vector:\n", col_vector)
print("1x4 row vector:\n", row_vector)
print("Broadcasted 3x4 multiplication table:\n", broadcasted_result)
# Out:
# 3x1 column vector:
#  [[1]
#  [2]
#  [3]]
# 1x4 row vector:
#  [[10 20 30 40]]
# Broadcasted 3x4 multiplication table:
#  [[ 10  20  30  40]
#  [ 20  40  60  80]
#  [ 30  60  90 120]]

# %% [markdown]
# 2. Vectorization vs Loops – Time Comparison

# %%
import numpy as np
import time

# Sample array
arr = np.arange(1_000_000)

# 1. Square using a for-loop
def square_with_loop(array):
    result = []
    for x in array:
        result.append(x ** 2)
    return result

# 2. Square using NumPy vectorization
def square_with_numpy(array):
    return array ** 2

# Timing the loop
start_time = time.time()
square_with_loop(arr)
loop_time = time.time() - start_time

# Timing the vectorized version
start_time = time.time()
square_with_numpy(arr)
vector_time = time.time() - start_time

print(f"Time taken with loop: {loop_time:.4f} seconds")
print(f"Time taken with NumPy vectorization: {vector_time:.4f} seconds")
# Out:
# Time taken with loop: 0.2400 seconds
# Time taken with NumPy vectorization: 0.0037 seconds

# %% [markdown]
# 3. Simulation Task

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Simulate 1000 coin tosses
coin_tosses = np.random.choice(['H', 'T'], size=1000)
heads_count = np.sum(coin_tosses == 'H')
heads_proportion = heads_count / 1000

print(f"Number of Heads: {heads_count}")
print(f"Proportion of Heads: {heads_proportion:.2f}")

# 2. Simulate 1000 dice rolls (values from 1 to 6)
dice_rolls = np.random.randint(1, 7, size=1000)

# 3. Plot histogram
plt.figure(figsize=(8, 4))
sns.histplot(dice_rolls, bins=6, kde=False, discrete=True, color='orange')
plt.title("Histogram of 1000 Dice Rolls")
plt.xlabel("Dice Face")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# Number of Heads: 512
# Proportion of Heads: 0.51

# %% [markdown]
# 4. Solving Systems of Equations

# %%
import numpy as np

# Coefficient matrix A
A = np.array([[3, 1],
              [9, 2]])

# Constants vector B
B = np.array([9, 8])

# Solve for [x, y]
solution = np.linalg.solve(A, B)

print("Solution [x, y]:")
print(solution)
# Out:
# Solution [x, y]:
# [-3.33333333 19.        ]

# %% [markdown]
# # Visualization with Matplotlib and Seaborn

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generate data
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)

# Plot
plt.figure(figsize=(8, 4))
plt.plot(x, y, label='sin(x)', color='teal')
plt.title("Line Plot of y = sin(x)")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.grid(True)
plt.legend()
plt.show()

# %%
# Histogram of Median House Value
plt.figure(figsize=(8, 4))
sns.histplot(df['MedHouseVal'], bins=30, kde=True, color='skyblue')
plt.title("Histogram of Median House Value")
plt.xlabel("MedHouseVal")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()

# %%
# Group by Region and compute average income
region_income = df.groupby('Region')['MedInc'].mean().reset_index()

# Plot
plt.figure(figsize=(6, 4))
sns.barplot(x='Region', y='MedInc', data=region_income, palette='pastel')
plt.title("Average Median Income by Region")
plt.xlabel("Region")
plt.ylabel("Average Median Income")
plt.grid(True)
plt.show()
# Out:
# /tmp/ipython-input-46-2986055982.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Region', y='MedInc', data=region_income, palette='pastel')

# %%
# Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='MedInc', y='MedHouseVal', hue='Region', alpha=0.6)
plt.title("Median Income vs House Value by Region")
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
plt.grid(True)
plt.show()

# Add regression line (Seaborn)
plt.figure(figsize=(8, 5))
sns.regplot(data=df, x='MedInc', y='MedHouseVal', scatter_kws={'alpha':0.3})
plt.title("Regression Line on MedInc vs MedHouseVal")
plt.xlabel("Median Income")
plt.ylabel("Median House Value")
plt.grid(True)
plt.show()

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 10))

# Line plot
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
axs[0, 0].plot(x, y, color='navy')
axs[0, 0].set_title("y = sin(x)")
axs[0, 0].grid(True)

# Histogram of MedInc
axs[0, 1].hist(df['MedInc'], bins=30, color='orange')
axs[0, 1].set_title("Histogram of Median Income")

# Bar chart: Region-wise population
region_pop = df.groupby('Region')['Population'].mean()
axs[1, 0].bar(region_pop.index, region_pop.values, color='lightgreen')
axs[1, 0].set_title("Average Population by Region")

# Boxplot: House Value by AgeGroup
sns.boxplot(x='AgeGroup', y='MedHouseVal', data=df, ax=axs[1, 1], palette='cool')
axs[1, 1].set_title("House Value by Age Group")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-48-1056807750.py:20: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='AgeGroup', y='MedHouseVal', data=df, ax=axs[1, 1], palette='cool')

# %% [markdown]
# # Advanced Visualization Exercises

# %%
# Compute correlation matrix
correlation_matrix = df.corr(numeric_only=True)

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Select relevant features
features = ['MedInc', 'MedHouseVal', 'HouseAge', 'AveRooms', 'Region']

# Pairplot
sns.pairplot(df[features], hue='Region', palette='husl')
plt.suptitle("Pairplot of Selected Features by Region", y=1.02)
plt.show()

# %%
# Original distribution
plt.figure(figsize=(8, 4))
sns.histplot(df['MedHouseVal'], kde=True, bins=30, color='steelblue')
plt.title("Distribution of Median House Value")
plt.xlabel("MedHouseVal")
plt.show()

# Log-transformed version
import numpy as np

df['LogMedHouseVal'] = np.log1p(df['MedHouseVal'])  # log1p handles 0 safely

plt.figure(figsize=(8, 4))
sns.histplot(df['LogMedHouseVal'], kde=True, bins=30, color='darkred')
plt.title("Log-Transformed Distribution of Median House Value")
plt.xlabel("Log(MedHouseVal)")
plt.show()
